# %%
import numpy as np 
import re
import pandas as pd

# %%
class Fatawa_Topic_Modeler():
    
    def Fit(df,column):
        df["Topics"] = None
        # صلاة  
        salah = df["ques"].str.contains("صلاة|يصلون|يصلي|صلاه|صلوا|صلوات|الصلوات")
        if salah.any():
            
            # صلاة الاستسقاء 
            keywords_sub = ["استسقاء", "الاستسقاء"]
            estska2 = df['ques'].str.contains('|'.join(keywords_sub))

            filter = estska2 

            if filter.any():
                df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'صلاة الاستسقاء'

            #---------------------------------------------------------------------------
            #صلاة الاستخاره 
            keywords_sub = ["الاستخارة","استخارة","استخاره", "الاستخاره"]
            est5ara = column.str.contains('|'.join(keywords_sub))
            filter = est5ara 
            if filter.any():
                df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'صلاة الاستخاره'
            #----------------------------------------------------------------------------
            # صلاة المريض

            keywords_sub = ["صلاة المريض","مرض","مرضي","مريض","صلاه المريض"]
            mrd = column.str.contains('|'.join(keywords_sub))   

            filter = mrd 

            if filter.any():
                df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'صلاة المريض'

            #------------------------------------------------------------------------------
            # صلاة الشفع و الوتر

            keywords_sub = ["الوتر","يوتر" "شفع","شفع","الشفع","يوترون", "يوتر"]
            shf3 = column.str.contains('|'.join(keywords_sub))        
            filter = shf3

            if filter.any():
                df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'صلاة الشفع و الوتر'

            #-----------------------------------------------------------------------------        
            # صلاة الجمعة

            keywords_sub = ["جمعه", "الجمعه", "الجمعة"]
            gom3a = column.str.contains('|'.join(keywords_sub))

            filter = gom3a

            if filter.any():
                df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'صلاة الجمعة'

            #------------------------------------------------------------------------------        
            # صلاة العيدين و يوم عرفه

            keywords = ["عرفه", "عرفة"]
            pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
            Aid = column.str.contains(pattern, regex=True)

            keywords_sub = ["عيد", "عيد الضحي", "عيد الفطر", "العيد", "الاضحي","ذبح", "اضحي", "الفطر","عيد"]
            Aid2 = column.str.contains('|'.join(keywords_sub))       

            filter = Aid | Aid2

            if filter.any():
                df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'صلاة العيدين و يوم عرفه'

            #--------------------------------------------------------------------------------        
            #صلاة الكسوف و الخسوف

            keywords_sub =  ["كسوف", "خسوف"]
            ksof = column.str.contains('|'.join(keywords_sub)) 

            filter = ksof & salah

            if filter.any():
                df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'صلاة الكسوف و الخسوف' 
                
                
            #--------------------------------------------------------------------------------        
            #صلاة الخوف
            keywords_sub =  ["خوف","خائف","خاف"]
            khwf = column.str.contains('|'.join(keywords_sub))  

            filter = khwf 

            if filter.any():
                df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'صلاة الخوف'
                
                
            df.loc[salah & df['Topics'].isnull(), 'Topics'] = 'الصلاة'
                
                
                
                
        #-------------------------------------------------------------------------------------------------------    
        #-------------------------------------------------------------------------------------------------------      
        #-------------------------------------------------------------------------------------------------------       
        #-------------------------------------------------------------------------------------------------------       

        # الاستسقاء 
        keywords_sub = ["استسقاء", "الاستسقاء"]
        estska2 = column.str.contains('|'.join(keywords_sub))

        filter = estska2

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الاستسقاء'


        #-----------------------------------------------------------------------------
        #  الاستخاره 
        keywords_sub = ["الاستخارة","استخارة","استخاره", "الاستخاره"]
        est5ara = column.str.contains('|'.join(keywords_sub))
        filter = est5ara

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الاستخاره'

        #-----------------------------------------------------------------------------        
        #  الشفع و الوتر
        keywords_sub = ["الوتر","يوتر" "شفع","شفع","الشفع","يوترون", "يوتر"]
        shf3 = column.str.contains('|'.join(keywords_sub))   
        filter = shf3

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الشفع و الوتر'

        #-----------------------------------------------------------------------------
        #المريض
        keywords_sub = ["صلاة المريض","مرض","مرضي","مريض","صلاه المريض"]
        mrd = column.str.contains('|'.join(keywords_sub)) 
        filter = mrd 

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'المريض'

        #------------------------------------------------------------------------------
        #الجمعة

        keywords_sub = ["جمعه", "الجمعه", "الجمعة"]
        gom3a = column.str.contains('|'.join(keywords_sub))
        filter = gom3a

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الجمعة'

        #------------------------------------------------------------------------------
        #  العيدين و يوم عرفه

        keywords = ["عرفه", "عرفة"]
        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        Aid = column.str.contains(pattern, regex=True)

        keywords_sub = ["عيد", "عيد الضحي", "عيد الفطر", "العيد", "الاضحي","ذبح", "اضحي", "الفطر","عيد"]
        Aid2 = column.str.contains('|'.join(keywords_sub))       

        filter = Aid | Aid2

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'العيدين و يوم عرفه'
        #------------------------------------------------------------------------------

        # الكسوف و الخسوف
        keywords_sub =  ["كسوف", "خسوف"]
        ksof = column.str.contains('|'.join(keywords_sub)) 

        filter = ksof 

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الكسوف و الخسوف'

        #------------------------------------------------------------------------------      
        # الخوف
        keywords_sub =  ["خوف","خائف","خاف"]
        khwf = column.str.contains('|'.join(keywords_sub))
        filter = khwf 

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الخوف'


        #-------------------------------------------------------------------------------

        # الجنائز
        keywords =  [ "الجنائز","جنائز","الجنازه","الجنازة","جنازة", "جنازه" ,"الكفن","تكفين", "تكفينه","يكفن","يكفنه","يكفنوا","يكفنون","المتوفى", "المتوفاة"
                     ,"ميت","يموت","يموت","يموتون","يموتون","يموتون","مات","ميت","مات","تموت","تموت","تموتون","تموتون","تموتين"
                     , "القبر","يقبر","يقبر","يقبرون","يقبرون","يقبرون","قبر","قبري","قبر","تقبر","تقبر","تقبرون","تقبرون","تقبرين","عزاء"
                     ,"الميت","الصلاه علي الميت", "الصلاة علي الميت","ميت" ]

        exclude_combinations = ["ورثه", "ورث" , "الميراث" , "ميراث" , "يرث" ,"الورثه"]

        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        gnaza = column.str.contains(pattern, regex=True) & ~column.str.contains('|'.join(map(re.escape, exclude_combinations)), regex=True)


        keywords_sub = ["ميت","قبر","موت","مات","جنازه","جنزة","توفي"]
        gnaza2 = column.str.contains('|'.join(keywords_sub))


        filter = gnaza | gnaza2

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الجنائز'

        #-------------------------------------------------------------------------------

        # الزكاه و الصدقات
        keywords =  ["يتصدقون","تصدقوا","تزكون","صدقه","تصدق", "يتصدق" ,"الزكاة","يزكي","يزكي","يزكون","يزكون","يزكون","زكى","زكوي","زكى","تزكي","تزكي","تزكون","صدقة","صدقه","أتصدق","تزكون","تكفّر","تزكين"
        ,"التصدق","الصدقه","بزكاة","الزكاة","كفارة","يكفر","لكفارة","ككفارة","بكفارة","الكفارة", "يتزكون","كفارتا","تزكي","يتزكي","زكاة","زكاه","الزكاه"]

        exclude_combinations = ["ورثه", "ورث" , "الميراث" , "ميراث" , "يرث" ,"الورثه", "الأجرة"]

        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        zkah = column.str.contains(pattern, regex=True) & ~column.str.contains('|'.join(map(re.escape, exclude_combinations)), regex=True)



        keywords_sub = ["زكاه","زكاة","تزكي","زكاه","تزكي","تصدق","صدقه","زكاة"]
        zkah2 = column.str.contains('|'.join(keywords_sub))        

        filter = zkah | zkah2

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الزكاه و الصدقات'

        #------------------------------------------------------------------------------

        # الصوم 

        keywords =  ["افطار","إفطار","سحور","السحور", "روية هلال" ,"رؤية هلال", "روية الهلال" ,"رؤية الهلال","تصوم", "تصومون","يصومون","صائم","يصوم","الصيام","رمضان","رمضان","شهر رمضان","الصوم","الإفطار","ورمضان","الافطار"]
        exclude_combinations = ["ورثه", "ورث" , "الميراث" , "ميراث" , "يرث" ,"الورثه", "الأجرة"]
        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        swm = column.str.contains(pattern, regex=True) & ~column.str.contains('|'.join(map(re.escape, exclude_combinations)), regex=True)


        keywords_sub = ["صوم","صيام","إفطار","هلال","تزكي","سحور","صائم","زكاة"]
        swm2 = column.str.contains('|'.join(keywords_sub))           
        filter = swm | swm2

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الصوم'

        #------------------------------------------------------------------------------
        # الحج و العمره 

        keywords = ["يعتمر","معتمر","عمره","العمره","عرفات","زمزم","الحج الإسلامي",  "الركن الخامس في الإسلام","مكة","الكعبة"," الحج","حج","الإحرام"," طواف", "منى","مزدلفة", "رمي الجمرات","رمي الجمر","الحرم المكي","حجاج","العمرة","الحجاج"]

        exclude_combinations = ["ورثه", "ورث" , "الميراث" , "ميراث" , "يرث" ,"الورثه", "الأجرة"]

        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        heg = column.str.contains(pattern, regex=True) & ~column.str.contains('|'.join(map(re.escape, exclude_combinations)), regex=True)


        keywords_sub = ["حجاج","جمر","كعبة","مكة","سحور","زمزم","معتمر","يعتمر","عمرة","منى","مزدلفة","إحرام","عمره"]
        heg2 = column.str.contains('|'.join(keywords_sub))       


        filter = heg | heg2

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الحج و العمره'

        #-------------------------------------------------------------------------------
        # الميراث 

        keywords = ["ورثه", "ورث" , "الميراث" , "ميراث" , "يرث" ,"الورثه","الورث","الميراث","الميراث",
                   "الورث","يرث","يرث","يرثون","يرثون","يرثن","ورث","ورثي","ورث","ترث"
                    ,"يرثون", "يرثون", "يرثن", "ورثي", "ترث", "ترثون", "ترثون", "ترثين"]


        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        meras = column.str.contains(pattern, regex=True) 



        keywords_sub = ["ورث","يرث","ميراث"]
        meras2 = column.str.contains('|'.join(keywords_sub))  


        filter = meras | meras2

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الميراث '

        #--------------------------------------------------------------------------------    
        # الماليات 

        keywords = ["المال", "ماليه", "شراء", "دفع", "يشتري", "شراء", "يشتري", "بالشيكات", "شيك", "الشيكات", "مال", "يشتري",
                     "يشترون", "يشترون", "يشترون", "اشترى", "اشتري",
                     "اشترى", "تشتري", "تشتري", "تشترون", "دفع", "يدفع", "يدفع", "يدفعون", "يدفعون", "يدفعن", "دفع", "نقود", "دفع",
                     "تدفع", "تدفع", "النقود", "تدفعون", "تدفعون", "المدين", "الدائن", "الديون", "الجود", "جود", "يدين", "تدفعين",
                     "تشترون", "البنك", "الربا", "ربا", "الربويه", "بنكي", "بنك", "الفوايد", "الفلوس", "استثمار", "يستثمر", "يستثمر",
                     "يستثمرون", "يستثمرون", "يستثمرن", "استثمر", "استثمري", "استثمر", "تستثمر", "تستثمر", "سلف", "تستثمرون", "تستثمرون",
                     "تستثمرين", "فوايد", "مصاريف", "مصاريف", "مصارف", "مصارف", "مصارف إسلامية", "باع", "يبيعون", "قرض", "البيع",
                     "التقسيط", "يقسط", "الرهن", "الرهانات", "يقسط", "رهن", "يقسطون", "يقسطون", "الفوائد", "يقسطون", "يمول", "تمويل",
                     "صكوك", "تأمينات", "تأمين", "قسط", "قسطي", "قسط", "الخزنه", "خزانة", "تقسط", "بيع بالتقسيط", "تقسط", "تقسطون",
                     "برصه", "البرصه", "المضاربة", "مضاربة", "التداول", "تقسطون", "تقسطين", "الحسابات", "بيع", "قروض", "الحسابات",
                     "والحسابات", "سعره", "الحسابات البنكية", "راتب", "تشترين", "عملة", "مناقصه", "مرابحة", "الأجرة"]

        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        mal = column.str.contains(pattern, regex=True)

        keywords_sub = ["مضاربة","قسط","تمويل","مكة","مال","يعتمر","دفع","شراء","سلف",
                        "استثمر","قرض","يشتري","لنقود","قسط","صكوك","اشترى","ربا","ربويه",
                        "بيع","فوايد","بنك","رهن","شراء","دائن","مدين","فلوس","رصة"]

        mal2 = column.str.contains('|'.join(keywords_sub))  
        filter = mal | mal2

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الماليات'

        #--------------------------------------------------------------------------------
        #الطهارة

        keywords = ["التيمم","يتيمم","يتيمم","يتيممون","يتيممون","يتيممن",
                    "تتيمم","تتيممي","تتيمم","تتيمم","تتيمم","تتيممن","تتيممن","العضو","الشهوة","الاغتسال" ,"الحائض","غسل","تتيممين"
                    "نفاس","الجنابة","يجنب","يجنب","يجنبون","يجنبون","يجنبن","جنب","جنبي","جنب",
                    "تجنب","تجنب","النفاس","تجنبن","تجنبن","تجنبين","الاستحمام","يستحمم","يستحمم","حيض","الحيض","يستحممون",
                    "يستحممن","يستحممن","استحمم","استحممي","استحمم","تستحمم","تستحمم","تستحممن","تستحممن","تستحممين","الوضوء",
                    "يتوضأ","يتوضأ","يتوضئون","يتوضئن","يتوضئن","توضأ","توضئي","توضئ","تتوضأ","تتوضأ","تتوضأن",
                    "تتوضأن","تتوضئين","اغتسل","الاستطابة","تغتسل","يغتسل","تغتسلين","تغتسلن","يغتسلن","اغتسلت","اغتسلتِ",
                    "اغتسلَ","الطاهر","اغتسلتا","اغتسلتما","اغتسلا","اغتسلتم","اغتسلوا","اغتسلي","اغتسلوا","نجس","طهاره",
                    "تطهاره","يتهاره","تطهارهين","تطهارهن","يطهارهن","تهارهت","القذارة","تهارهتِ","تهارهتَ",
                    "الدورة الشهرية","دورة الشهرية","نجاسة","النجاسة","دورة شهرية","تهارهتا","الاستطابة",
                    "البول","بول","التبرز","تهارهتما","تهارهوا","الجنس","جنس","تهارهتم","تهارهوا","تهارهي","تهارهي"]

        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        cleaning = column.str.contains(pattern, regex=True)



        keywords_sub = ["اغتسلوا","اغتسل","طاهر","توضأ","استحم","يستحم","غتسل","توضئ", "غسل","وضوء","نفاس","شعر",
                        "جنب","استطاب","نجس","نجاسة","نجاسه","لتبرز","طهاره","قذارة","بول","جنس","تيمم","جنابة","طهر"]
        cleaning2 = column.str.contains('|'.join(keywords_sub)) 


        filter= cleaning | cleaning2


        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الطهارة'

        #----------------------------------------------------------------------------------

        #السفر

        keywords =["الطائرة","السفر","يسافر","يسافر","يسافرون","يسافرون","يسافرن","سافر",
                   "سافري","سافر","تسافر","المسافر","تسافر","سفر","تسافرون","الرحلة","تسافرون","تسافرين"]

        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        safr = column.str.contains(pattern, regex=True)

        keywords_sub = ["طائرة","رحلة","سفر","سافر"]
        safr2 = column.str.contains('|'.join(keywords_sub))        

        filter = safr | safr2

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'السفر'



        #----------------------------------------------------------------------------------        
        # الزواج و الطلاق 

        keywords = ["طلاق","يطلق","يطلق","يطلقون","يطلقون","يطلقن","طلق","طلقي","طلق","تطلق","تطلق","تطلقون","تطلقون","عقد قرانها","قران","قرانها","عقد قران","تطلقين"
        ,"الزوج","يتزوج","يتزوج","الحب","يحب","يحب","يحبون","يحبون","يحبن","حب","حبي","حب","تحب","تحب","تحبون","تحبون","تحبين"
        "الحب","يحب","يحب","يحبون","يحبون","يحبن","حب","حبي","حب","تحب","تحب","تحبون","تحبون","تحبين"
        ,"يتزوجون","يتزوجون","يتزوجن","تزوج","تزوجي","تزوج","تتزوج","تتزوج","تتزوجون","تتزوجون","تتزوجين",
        "أزوج","نزوج","أزوجوا","يتزوجن","تتزوجن","نتزوج","أزوجي","نزوجوا","نتزوج","زوج","زوجه","زوجها","زوجته","ازواج",
        "المطلقة ","للزوج","نسب","النسب","للزوجه","العدة","والزوج","والزواج","والزوجه","للزواج","الازواج"
        ,"عريس","عروسه","عريسي","عريستي","العريس","العروسه","الزواج","زواجي","متزوجه" ,"للزوج"
        ,"النفقه","نفقه","ينفق","النفقات"]

        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        tla2 = column.str.contains(pattern, regex=True)        


        keywords_sub = ["زواج","زوج","نفقه","عريس","نسب","طلق","طلاق","خلع"]
        tla22 = column.str.contains('|'.join(keywords_sub))           

        filter = tla2 | tla22

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الزواج و الطلاق'        

        #--------------------------------------------------------------------------------

        # القراءات و التلاوات
        keywords_sub = ["عاصم","حفص","تلاوه","قراءة","تجويد","قراءات","مقام","ترتيل","تفسير","معنى","القرآن الكريم","ما معنى الحديث الشريف","صحة",".ما صحة","ما صحة","ما معنى","القرآن","مقرئ",
                        "القراءات","ورش","الإمامية","الوقف","الابتداء ","الإنقطاع","سكت","تفخيم","ترقيق", "تجويد"
                        "إمالة","مد","مدود","قمري","متواترة","وتر","تنوين"," الساكنة","ترتيل"]
        tlawa = column.str.contains('|'.join(keywords_sub))        
        filter = tlawa 

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'القراءات و التلاوات'        

        #--------------------------------------------------------------------------------

        #الصلاة  
        keywords = ["المسجد","مغرب","فجر","الضحى","الشروق","شروق","إمام","ضحى"
                    ,"الفجر","عشاء","العشاء","ضهر","الضهر","ركعات","ركعه","الركوع","الركوع","يركع","يركع"
                    ,"يركعون","يركعون","يركعن","ركع","ركعي","ركع","تركع","تركع","المصلي","مصلي","المسجد",
                    "مسجد","إمام","تركعن","تركعن","تركعين","السجود","يسجد","يسجد","يسجدون","يسجدون","يسجدن",
                    "سجد","سجدي","سجد","تسجد","تسجد","تسجدن","تسجدن","تسجدين","ركع","قيام الليل","عصر",
                    "العصر","امامة","يؤمم","يؤمم","يؤممون","يؤممون","يؤممن","ؤمم","ؤممي","ؤمم","تؤمم","تؤمم"
                    ,"تؤممن","تؤممن","تؤممين","خطب","نصلي","المغرب"]



        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        prayer = df["ques"].str.contains(pattern, regex=True)

        keywords_sub = ["سجود","سجد","ركوع","ركع","تؤمم","امام","مصلي","خطب"]
        prayer2 = column.str.contains('|'.join(keywords_sub))        

        filter = prayer | prayer2 | salah

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الصلاة'

        #--------------------------------------------------------------------------------

        # الاديان
        keywords_sub = ["مسيح","نجيل","توراه","يهود","الحاد","هندوس","بوز","صوف","نجيل","بودا",
                        "ديانة","مقدس","صلب ","صليب","زرادشتية","توحيد ","تثليث","زهديه ","معمودية","شيعيا","شيعي","جيني","شنتو","سيخي",
                       "رفضية","كريشنامورتي","يزيدية","بيزنطي","علوي","شاماني","شيعه","شيعة","اشاعر","سلف","حنابل"]

        adyan = column.str.contains('|'.join(keywords_sub))        
        filter = adyan 

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الاديان'   



        #--------------------------------------------------------------------------------

        # يوم القيامة

        keywords = ["القيامة","يوم القيامة","الاخره","الجنه","النار","الجنه","جنه"]

        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        hokm = column.str.contains(pattern, regex=True)

        filter = hokm 
        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'يوم القيامة'

        #--------------------------------------------------------------------------------

        # الجهاد            

        keywords_sub_gehad = ["جهاد","جاهد"]
        gehad = column.str.contains('|'.join(keywords_sub_gehad))  

        filter = gehad 
        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الجهاد'        


        #--------------------------------------------------------------------------------
        # اعتكاف            

        keywords_sub_e3tkaf = ["عتكاف","عتكف"]
        e3tkaf = column.str.contains('|'.join(keywords_sub_e3tkaf))  

        filter = e3tkaf 
        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] ='إعتكاف' 
        #----------------------------------------------------------------------------------        
        # المعازف و الموسيقي 


        keywords = ["لحن","راب","شاعر"]
        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        m3azf = column.str.contains(pattern, regex=True)        


        keywords_sub = ["عزف","ألحان","جيتار","موسيق","شيللو","ساكس","طبل","كمان","غناء","مطرب","أغني","إيقاع","غنية","نغمة"]
        m3azf2 = column.str.contains('|'.join(keywords_sub))           

        filter = m3azf | m3azf2

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'المعازف و الموسيقي' 

        #----------------------------------------------------------------------------------        
        # الملابس 

        keywords = ["جيب","برقع","النقاب"]
        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        mlabs = column.str.contains(pattern, regex=True)        


        keywords_sub = ["حجاب","ملابس","قميص","قميص","بنطلون","فستان","شفاف"
                        ,"بلوز","لبس","شبشب","سروال","معطف","شماغ","عباية",
                        "حذاء","بيكيني","جلباب","خمار","طرحة","عباءة","بدلة","لباس"]

        mlabs2 = column.str.contains('|'.join(keywords_sub))           

        filter = mlabs | mlabs2

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الملابس'    

        #--------------------------------------------------------------------------------

        #الايتام و التبني  


        keywords = ["رعاية أطفال"]
        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        aytam = column.str.contains(pattern, regex=True)        


        keywords_sub = ["يتيم","ايتام","تبني"]

        aytam2 = column.str.contains('|'.join(keywords_sub))           

        filter = aytam | aytam2

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الايتام و التبني'    

        #--------------------------------------------------------------------------------
        #العدل و المسواة  


        keywords = ["فساد"]
        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        adl = column.str.contains(pattern, regex=True)        


        keywords_sub = ["مساواة","عدل","قانون","فساد"]

        adl2 = column.str.contains('|'.join(keywords_sub))           

        filter = adl | adl2

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'العدل و المسواة'    

        #--------------------------------------------------------------------------------

        #الحيوانات


        keywords = ["فساد"]
        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        adl = column.str.contains(pattern, regex=True)       

        keywords_sub = ["قطط", "كلاب", "كلب", "زواحف", "حشرا", "أسماك", "ليفة","حيوان","أسماك","سمك"
                        "مفترس", "عاشبة", "طيور", "ثدييات", "فيل", "جمل", "فهد", "نمر", "فرس نهر",
                        "سلحفاة", "ضفدع", "فأر", "أسد", "قرد", "غزال", "خروف", "بقرة", "حمار",
                        "حصان", "ثعبان", "عقرب", "نملة", "نحلة", "بطة", "ديك", "خنزير", "ثعلب",
                        "سمكة", "حوت", "دلفين", "تمساح", "قرش", "سمك السلمون", "زرافة", "حمامة",
                        "نسر", "بومة", "فهد", "تمساح", "قرد", "زرافة", "أفعى", "سمك القرش", "سلحفاة"]


        adl2 = column.str.contains('|'.join(keywords_sub))           

        exclude_combinations = ["خطير","يطير"]
        adl3 = column.str.contains('|'.join(exclude_combinations))        

        filter = (adl | adl2) & ~adl3

        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'الحيوانات'    

        #--------------------------------------------------------------------------------   
        # احكام

        keywords = ["الحكم الشرعي","ما حكم","هل يجوز","فما هما","ماهوحكم","ماالحكم","والحكم","الحكمه","بحكم","هوحكم","ما معني","ماحكم","هل تصح","هل تصح",
                    "حكمه","حكمهما","يحكم","حكم","ماهوحكم","يحكم","يحكم","يحكمون",
                    "يحكمون","يحكمون","حكم","حكمي","حكم","تحكم","تحكم","تحكمون","تحكمون","تحكمين",
                    "ماهو حكم","ماالحكمة",".ماالحكمة","حكمها","وما حكمها","ماهوالحكم","الحكمة","حكم","الحكم"]

        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        hokm = column.str.contains(pattern, regex=True)

        filter = hokm 
        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'احكام'

        #--------------------------------------------------------------------------------
        # استفسارات عامه

        keywords = ["ما هو","ماهو","من","من هو","ما","","ما",
            "هل", "ما", "من", "أين", "متى", "كيف", "لماذا", "كم", "هل يمكنني", "هل تستطيع",
            "من فضلك", "هل يمكنك أن", "أي", "أيّان", "كيف يمكنني", "هل يجب أن", "كم من الوقت",
            "منذ متى", "هل يمكننا", "هل يمكنهم", "هل تعرف", "ماذا تعني", "هل توافق", "هل تحب",
            "هل يمكنني الحصول على", "كيف أستخدم", "هل يمكنني أخذ", "كيف أصل إلى", "هل يمكنني الذهاب إلى",
            "ما هو", "ماذا يعني", "ما هي الطريقة الصحيحة ل", "كيف أتعلم", "هل يجب أن أفعل",
            "ماذا يمكنني أن أفعل إذا", "كيف يعمل", "هل يمكنني طلب", "هل هناك", "ما هو السبب في",
            "من هو المسؤول عن", "هل هذا صحيح", "هل يوجد", "ماذا تفعل", "ماذا يجب أن أفعل",
            "ماذا أفعل إذا", "هل يمكنني مساعدتك", "كيف يمكنني الوصول إلى", "هل هناك أي شيء",
            "ما الذي يجعلك سعيدًا", "كيف يمكنني التواصل مع", "هل تعتقد أن", "كيف تعرف", "هل يمكنني الانضمام إلى",
            "ما الذي يجب أن أعرف عن", "من أين تعرف", "هل هذا ممكن", "هل تعتقد أنه من الممكن",
            "ماذا يعتقد الناس عن", "كيف يبدو", "هل يمكنني الحصول على نسخة من", "كم تستغرق",
            "هل توافقني", "هل ترغب في", "ما هي خططك ل", "كيف تختار", "هل تعلم من يمكنني الحصول على",
            "هل هذا ضروري", "ما الذي ستفعله إذا فزت ب", "كيف يمكنني حل", "هل هناك أي شيء آخر"]

        pattern = r'\b(?:{})\b'.format('|'.join(map(re.escape, keywords)))
        as2la_3ma = column.str.contains(pattern, regex=True)

        filter = as2la_3ma 
        if filter.any():
            df.loc[filter & df['Topics'].isnull(), 'Topics'] = 'استفسارات عامة'

    #--------------------------------------------------------------------------------

        df.loc[df['Topics'].isnull(), 'Topics'] = 'آخرون'

        
        
    def predict_dirict(input_string):
        data = {'ques': [input_string]}

        df = pd.DataFrame(data)
        Fatawa_Topic_Modeler.Fit(df,df["ques"])
        return df["Topics"].iloc[0]
        #string_df.head()

# %%
Fatawa_Topic_Modeler.predict_dirict('حكم شراء السيارة بالأقساط المريحة من بنك رب')
# Out:
# 'الماليات'
